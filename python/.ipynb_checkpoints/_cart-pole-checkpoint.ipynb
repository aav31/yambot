# %%
""" Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym. """
import numpy as np
import pickle
import gymnasium as gym
import random
import time

# %%
# hyperparameters
H = 5 # number of hidden layer neurons
batch_size = 100 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = True # resume from previous checkpoint?
render = False

# model initialization
D = 4
if resume:
  model = pickle.load(open('save.p', 'rb'))
else:
  model = {}
  model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
  model['W2'] = np.random.randn(H) / np.sqrt(H)
  
grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(range(0, r.size)):
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of going right

def policy_backward(eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backprop relu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

env = gym.make("CartPole-v1") if not render else gym.make("CartPole-v1",render_mode='human')
observation, _ = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0

while True:
  x = observation

  # forward the policy network and sample an action from the returned probability
  aprob, h = policy_forward(x)
  action = 1 if np.random.uniform() < aprob else 0 # 0 means go left, 1 means go right, aprob is probability of going right

  # record various intermediates (needed later for backprop)
  xs.append(x) # observation
  hs.append(h) # hidden state
  y = action # a "fake label"
  dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

  # step the environment and get new measurements
  observation, reward, terminated, _, _ = env.step(action)
  reward_sum += reward

  drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

  if terminated: # an episode finished
    episode_number += 1

    # stack together all inputs, hidden states, action gradients, and rewards for this episode
    epx = np.vstack(xs)
    eph = np.vstack(hs)
    epdlogp = np.vstack(dlogps)
    epr = np.vstack(drs)
    xs,hs,dlogps,drs = [],[],[],[] # reset array memory

    # compute the discounted reward backwards through time
    discounted_epr = discount_rewards(epr)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_epr -= np.mean(discounted_epr)
    discounted_epr /= np.std(discounted_epr)

    epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
    grad = policy_backward(eph, epdlogp)
    for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

    # perform rmsprop parameter update every batch_size episodes
    if episode_number % batch_size == 0:
      for k,v in model.items():
        g = grad_buffer[k] # gradient
        rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
        model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
        grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

    # boring book-keeping
    running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
    if episode_number % (batch_size * 100) == 0: print('resetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
    if episode_number % batch_size == 0: pickle.dump(model, open('save.p', 'wb'))
    reward_sum = 0
    observation, _ = env.reset() # reset env
    prev_x = None

  if reward != 1:
    print('Unexpected reward episode {}: reward: {} terminated: {}'.format(episode_number, reward, terminated))

env.close()
# Out:
# resetting env. episode reward total was 84.000000. running mean: 43.253248
# resetting env. episode reward total was 39.000000. running mean: 48.988369
# resetting env. episode reward total was 55.000000. running mean: 46.107175
# resetting env. episode reward total was 52.000000. running mean: 51.670048
# resetting env. episode reward total was 18.000000. running mean: 48.478837
# resetting env. episode reward total was 72.000000. running mean: 54.028256
# resetting env. episode reward total was 93.000000. running mean: 52.038333
# resetting env. episode reward total was 35.000000. running mean: 60.228856
# resetting env. episode reward total was 51.000000. running mean: 52.669171
# resetting env. episode reward total was 44.000000. running mean: 50.985463
# resetting env. episode reward total was 99.000000. running mean: 58.093595
# resetting env. episode reward total was 48.000000. running mean: 55.255728
# resetting env. episode reward total was 15.000000. running mean: 58.728305
# resetting env. episode reward total was 90.000000. running mean: 65.678227
# resetting env. episode reward total was 35.000000. running mean: 56.834924
# resetting env. episode reward total was 26.000000. running mean: 67.363807
# resetting env. episode reward total was 94.000000. running mean: 61.208094
# resetting env. episode reward total was 65.000000. running mean: 71.005688
# resetting env. episode reward total was 33.000000. running mean: 72.687254
# resetting env. episode reward total was 51.000000. running mean: 68.620591
# resetting env. episode reward total was 114.000000. running mean: 65.275832
# resetting env. episode reward total was 93.000000. running mean: 67.227330
# resetting env. episode reward total was 205.000000. running mean: 69.509479
# resetting env. episode reward total was 138.000000. running mean: 75.926135
# resetting env. episode reward total was 11.000000. running mean: 73.767548
# resetting env. episode reward total was 53.000000. running mean: 76.939123
# resetting env. episode reward total was 32.000000. running mean: 82.573117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 61
#      58 x = observation
#      60 # forward the policy network and sample an action from the returned probability
# ---> 61 aprob, h = policy_forward(x)
#      62 action = 1 if np.random.uniform() < aprob else 0 # 0 means go left, 1 means go right, aprob is probability of going right
#      64 # record various intermediates (needed later for backprop)
#
# Cell In[43], line 35, in policy_forward(x)
#      34 def policy_forward(x):
# ---> 35   h = np.dot(model['W1'], x)
#      36   h[h<0] = 0 # ReLU nonlinearity
#      37   logp = np.dot(model['W2'], h)
#
# KeyboardInterrupt:

# %%
model = pickle.load(open('save.p', 'rb'))
env = gym.make("CartPole-v1",render_mode='human')
observation, _ = env.reset()
terminated = False
reward_sum = 0
while not terminated:
    x = observation
    # forward the policy network and sample an action from the returned probability
    aprob, h = policy_forward(x)
    action = 1 if aprob > 0.5 else 0 # 0 means go left, 1 means go right, aprob is probability of going right
    observation, reward, terminated, _, _ = env.step(action)
    reward_sum += reward

print(reward_sum)
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 11
#       9     aprob, h = policy_forward(x)
#      10     action = 1 if aprob > 0.5 else 0 # 0 means go left, 1 means go right, aprob is probability of going right
# ---> 11     observation, reward, terminated, _, _ = env.step(action)
#      12     reward_sum += reward
#      14 print(reward_sum)
#
# File ~\miniconda3\envs\cart-pole\Lib\site-packages\gymnasium\wrappers\time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\miniconda3\envs\cart-pole\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~\miniconda3\envs\cart-pole\Lib\site-packages\gymnasium\wrappers\env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~\miniconda3\envs\cart-pole\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:189, in CartPoleEnv.step(self, action)
#     186     reward = 0.0
#     188 if self.render_mode == "human":
# --> 189     self.render()
#     190 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~\miniconda3\envs\cart-pole\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:300, in CartPoleEnv.render(self)
#     298 if self.render_mode == "human":
#     299     pygame.event.pump()
# --> 300     self.clock.tick(self.metadata["render_fps"])
#     301     pygame.display.flip()
#     303 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# 1119.0
